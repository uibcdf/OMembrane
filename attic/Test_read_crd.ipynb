# %%
import molsysmt as msm

# %%
molsys = './popc/conf1/popc_1.crd'

# %%
molsys = msm.convert(molsys)
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 molsys = msm.convert(molsys)
#
# File ~/Myopt/miniconda3/envs/OpenMembrane@dprada_3.9/lib/python3.9/site-packages/molsysmt/_private/digestion/digest.py:105, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     102     pass
#     104 for arg_name in all_args:
# --> 105     gut(arg_name)
#     107 for arg_name in not_digested_args:
#     108     if arg_name not in ['self']:
#
# File ~/Myopt/miniconda3/envs/OpenMembrane@dprada_3.9/lib/python3.9/site-packages/molsysmt/_private/digestion/digest.py:97, in digest.<locals>.digestor.<locals>.wrapper.<locals>.gut(arg_name)
#      95         else:
#      96             parameters_dict[parameter] = None
# ---> 97     digested_args[arg_name] = digestion_functions[arg_name](all_args[arg_name],
# ...
