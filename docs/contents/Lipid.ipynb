# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm

# %% [markdown]
# # Test with a lipid

# %%
file_crd = '../../popc/conf1/popc_462.crd'

# %%
file_pdb = msm.demo_systems.files['1tcd.pdb']

# %%
system = msm.convert(file_pdb, to_form='pytraj.Topology')

# %%
system_msm = msm.convert(file_pdb, to_form='molsysmt.Topology')

# %%
msm.get(system, target='atom', molecule_name=True)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-40-bd6c923aed32> in <module>
# ----> 1 msm.get(system, target='atom', molecule_name=True)
#
# ~/Projects/MolSysMT/molsysmt/multitool.py in get(item, target, indices, selection, frame_indices, syntaxis, **kwargs)
#     965     results = []
#     966     for attribute in attributes:
# --> 967         result = _dict_get[form_in][target][attribute](item, indices=indices, frame_indices=frame_indices)
#     968         results.append(result)
#     969
#
# ~/Projects/MolSysMT/molsysmt/forms/classes/api_pytraj_Topology.py in get_molecule_name_from_atom(item, indices, frame_indices)
#     256 def get_molecule_name_from_atom (item, indices='all', frame_indices='all'):
#     257
# --> 258     raise NotImplementedError
#     259
#     260 def get_molecule_type_from_atom (item, indices='all', frame_indices='all'):
#
# NotImplementedError:

# %%
msm.get(system_msm, target='atom', molecule_type=True)
# Out:
# array(['protein', 'protein', 'protein', ..., 'water', 'water', 'water'],
#       dtype=object)

# %%
import numpy as np

# %%
aa=np.array([3,4,5,6])

# %%
dd = dict(zip(aa,range(4)))

# %%
np.vectorize(dd.__getitem__)(aa)
# Out:
# array([0, 1, 2, 3])

# %%
cc = dict(aa,zip(range(4)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-b1da54de8118> in <module>
# ----> 1 cc = dict(aa,zip(range(4)))
#
# TypeError: dict expected at most 1 arguments, got 2

# %%
cc
# Out:
# {0: 3, 1: 4, 2: 5, 3: 6}

# %%
bb.fromkeys(np.arange(aa.shape[0]), aa)
# Out:
# {0: array([3, 4, 5, 6]),
#  1: array([3, 4, 5, 6]),
#  2: array([3, 4, 5, 6]),
#  3: array([3, 4, 5, 6])}

# %%
aa = system.residue(0)

# %%
aa.original_resid

# %%
aa = list(system.mols)[0]

# %%
help(aa)

# %%
mol=list(system.mols)[0]

# %%
aa=system.atom(0)

# %%
aa.
# Out:
# 0
