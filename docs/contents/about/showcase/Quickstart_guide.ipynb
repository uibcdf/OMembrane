# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

# %% [markdown]
# # Quickstart guide

# %% [markdown]
# ## Ready in two steps
#
# Install OpenMembrane in your conda env:
#
# ```bash
# conda install -c uibcdf openmembrane
# ```

# %% [markdown]
# and open a Jupyter notebook or an IPython session to import the library:

# %%
import openmembrane as omem

# %% [markdown]
# ## Building a membrane
#
# ...

# %% [markdown]
# ## Analysis
#
# ...
